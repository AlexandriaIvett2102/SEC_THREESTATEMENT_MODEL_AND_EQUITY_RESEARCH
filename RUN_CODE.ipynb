# %%
# %load_ext autoreload
# %autoreload 2
# Just imports the plugin so that it can run all the seperate files together. Put all related files in a single folder and run with this file

import competitor_intel_plugin
